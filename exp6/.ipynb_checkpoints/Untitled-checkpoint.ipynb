# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import pandas as pd

# %%
df=pd.read_csv("touch.csv")
df.columns=[c.strip for c in df.columns]
V=df.iloc[:,0]
I=df.iloc[:,1]
T_high=df.iloc[:,2]
T_low=df.iloc[:,3]
